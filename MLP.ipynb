# %%
import pandas as pd

# Load the uploaded datasets
X_train = pd.read_csv('C:/Users/PC/Downloads/output_csvs/X_train_selected1.csv')
y_train = pd.read_csv('C:/Users/PC/Downloads/output_csvs/y_train_selected1.csv')
X_test = pd.read_csv('C:/Users/PC/Downloads/output_csvs/X_test_selected1.csv')
y_test = pd.read_csv('C:/Users/PC/Downloads/output_csvs/y_test_selected1.csv')

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

# Define the MLP model with 82, 32, 10 neurons for the hidden layers
mlp = MLPClassifier(hidden_layer_sizes=(82, 32), max_iter=500, random_state=42)

# Train the model on the training data
mlp.fit(X_train, y_train.values.ravel())

# Predict on the test data
y_pred = mlp.predict(X_test)

# Evaluate the model's performance
report = classification_report(y_test, y_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.48      0.44      0.46       102
#            2       0.40      0.41      0.40        86
#            3       0.21      0.22      0.22        58
#            4       0.30      0.33      0.31        54
#            5       0.23      0.22      0.23        58
#            6       0.35      0.35      0.35        72
#            7       0.10      0.10      0.10        21
#            8       0.41      0.40      0.40        60
#            9       0.43      0.44      0.43       105
#           10       0.49      0.49      0.49       119
#
#     accuracy                           0.38       735
#    macro avg       0.34      0.34      0.34       735
# weighted avg       0.38      0.38      0.38       735
# ...

# %%
# Hiển thị confusion matrix để xem kết quả phân loại theo từng lớp
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=range(1, 11), yticklabels=range(1, 11))
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
